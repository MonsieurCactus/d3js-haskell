-- %%
writeToHtml :: (Reifiable a) => FilePath -> a -> IO ()
-- Out:
-- The type signature for ‘writeToHtml’ lacks an accompanying binding
--
--
-- Not in scope: type constructor or class ‘Reifiable’

-- %%
-- what exactly is the function reify acting on?  It is acting on Reifiable types.

-- In the file D3JS/Type.hs we learn how the Reifiable TypeClass is defined.

-- what is a Haskell class? it is a TypeClass

-- 

import Data.Text (Text)

class Reifiable a where
	reify :: a -> Text

-- %%
writeToHtml path a = T.writeFile path $ T.concat ["<html> <head><body> <div id='body'></div> <script src='", d3jsUrl, "' charset='utf-8'></script> <script charset='utf-8'>\n", reify a, "\n</script> </body> </html>"]

d3jsUrl = "http://d3js.org/d3.v3.min.js"
-- Out:
-- Not in scope: ‘T.writeFile’
--
--
-- Not in scope: ‘T.concat’

-- %%
import qualified Data.Text as T 
import qualified Data.Text.IO as T

-- %%
d3jsUrl = "http://d3js.org/d3.v3.min.js"

page a = ["<html> <head><body> <div id='body'></div> <script src='", d3jsUrl, "' charset='utf-8'></script> <script charset='utf-8'>\n", reify a, "\n</script> </body> </html>"]
-- Out:
-- Couldn't match expected type ‘String’ with actual type ‘Text’
-- In the expression: reify a
-- In the expression:
--   ["<html> <head><body> <div id='body'></div> <script src='", interactive:Ghci39.d3jsUrl, "' charset='utf-8'></script> <script charset='utf-8'>\n", reify a,
--    "\n\
--    \</script> </body> </html>"]

-- %%
writeToHtml path a = T.writeFile path $ T.concat page a
-- Out:
-- Not in scope: ‘page’

-- %%
reify x
-- Out:
-- Not in scope: ‘x’

-- %%
type Var = Text
instance Reifiable Var where
	reify t = t
-- Out:
-- Illegal instance declaration for ‘Reifiable interactive:Ghci85.Var’
--   (All instance types must be of the form (T t1 ... tn)
--    where T is not a synonym.
--    Use TypeSynonymInstances if you want to disable this.)
-- In the instance declaration for ‘Reifiable interactive:Ghci85.Var’

-- %%
-- with typeclasses always nearby are functors
